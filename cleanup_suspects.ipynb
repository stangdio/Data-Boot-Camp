# %%
import pandas as pd
import numpy as np

# %%
# 1. LOAD THE DATA
df = pd.read_csv('Suspects_Dataset.csv')

# %%
# 2. INITIAL EXPLORATION (what you already ran)
print("=== INITIAL DATA OVERVIEW ===")
df.info()
print("\n=== INITIAL MISSING VALUES ===")
print(df.isnull().sum())
# Out:
# === INITIAL DATA OVERVIEW ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   importtIndex_Monster  10000 non-null  int64
#  1   Monster               10000 non-null  object
#  2   Criminal record       10000 non-null  object
#  3   Age                   9995 non-null   float64
#  4   Gender                10000 non-null  object
#  5   Height in cm          10000 non-null  float64
#  6   Speed Level           9999 non-null   float64
#  7   Strength Level        9996 non-null   float64
#  8   Allergy               10000 non-null  object
#  9   Favorite Food         9998 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 781.4+ KB
#
# === INITIAL MISSING VALUES ===
# importtIndex_Monster    0
# Monster                 0
# Criminal record         0
# Age                     5
# Gender                  0
# Height in cm            0
# Speed Level             1
# Strength Level          4
# Allergy                 0
# Favorite Food           2
# dtype: int64

# %%
# 3 FIND SPECIFIC ROWS WITH MISSING DATA (NEW)
print("\n=== MONSTERS WITH MISSING DATA ===")
missing_rows = df[df.isnull().any(axis=1)]
print(f"Number of monsters with missing data: {len(missing_rows)}")
print(missing_rows[['Monster', 'Age', 'Speed Level', 'Strength Level', 'Favorite Food']])
# Out:
# === MONSTERS WITH MISSING DATA ===
# Number of monsters with missing data: 12
#        Monster    Age  Speed Level  Strength Level Favorite Food
# 278   Skeleton    NaN         30.0             6.0   pesto pasta
# 439     Zombie    NaN         12.0             1.0       lasagna
# 1083   Vampire  752.0         32.0             4.0           NaN
# 1643     Witch    NaN         24.0             5.0         brain
# 1873  Werewolf  123.0         62.0             6.0           NaN
# 1918  Werewolf   58.0         95.0             NaN          rats
# 2194    Zombie    NaN         17.0             1.0          rats
# 3903   Vampire  440.0         37.0             NaN          rats
# 4027   Vampire  611.0          NaN             6.0       lasagna
# 4565     Witch  722.0         17.0             NaN          rats
# 5068  Werewolf  137.0         77.0             NaN       lasagna
# 7216    Zombie    NaN         23.0             5.0         brain

# %%
# 4. samrt filling missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Speed Level'] = df['Speed Level'].fillna(df['Speed Level'].median())
df['Strength Level'] = df['Strength Level'].fillna(df['Strength Level'].median())
df['Favorite Food'] = df['Favorite Food'].fillna(df['Favorite Food'].mode()[0])

df
# Out:
#       importtIndex_Monster   Monster Criminal record     Age Gender  \
# 0                     2101     Witch              No   526.0      F
# 1                     9299    Zombie             Yes    46.0      M
# 2                     6824   Vampire              No   442.0      M
# 3                     6773   Vampire              No   551.0      F
# 4                     9624    Zombie             Yes   150.0      F
# ...                    ...       ...             ...     ...    ...
# 9995                  4633  Skeleton             Yes  1836.0      F
# 9996                  6713  Werewolf              No    77.0      F
# 9997                  5535     Witch              No   484.0      M
# 9998                  8635   Vampire              No   824.0      F
# 9999                  6340     Witch              No   442.0      M
#
#       Height in cm  Speed Level  Strength Level   Allergy Favorite Food
# 0            197.0         16.0             1.0  hazelnut         brain
# 1            184.0         20.0             7.0  cat hair        humans
# 2            192.0         21.0             7.0  sunlight   pesto pasta
# 3            167.0         43.0             6.0    garlic        humans
# 4            176.0         17.0             1.0   pumpkin         brain
# ...            ...          ...             ...       ...           ...
# 9995         152.0          1.0             2.0    silver          rats
# 9996         192.0         74.0             4.0    silver          rats
# 9997         175.0         18.0             2.0    garlic   pesto pasta
# 9998         152.0         31.0             5.0    silver       lasagna
# 9999         189.0         21.0             9.0   pumpkin       lasagna
#
# [10000 rows x 10 columns]

# %%
# make everything lower case

object_cols = df.select_dtypes(include='object').columns
for attribute in object_cols:
    df[attribute] = df[attribute].str.lower()
    print(df[attribute].unique())
# Out:
# ['witch' 'zombie' 'vampire' 'skeleton' 'werewolf' 'ghost']
# ['no' 'yes']
# ['f' 'm']
# ['hazelnut' 'cat hair' 'sunlight' 'garlic' 'pumpkin' 'silver']
# ['brain' 'humans' 'pesto pasta' 'rats' 'lasagna']

# %%
# # categorize Gender & Criminal Record

# columns = df.columns.values

# def encode(col):
#     code, unique = pd.factorize(df[col])
#     df[col] = code
#     mapping = dict(enumerate(unique))
#     print(mapping)

# encode('Gender')
# encode('Criminal record')

# %%
df['Age'].max()
df['Age Bin'] = pd.qcut(df['Age'], 6, labels = ['baby','teen', 'young adult', 'adult', 'middle age', 'old'])

# %%
print(df['Speed Level'].unique())
print(df['Speed Level'].min())
print(df['Speed Level'].max())
# Out:
# [ 16.  20.  21.  43.  17.  12.  38.  64.  22.  83.  78.  19.   7.   1.
#   49.   9.   3.  32.  31.  11.  41.  67.  18.  46.  79.  28.  26.  29.
#   90.  15.  13.  51.  55.  36. 100.  74.  60.  59.  69.  71.  52.  40.
#   73.  30.  23.  39.  70.  24.   6.  37.  57.  93.  89.  48.  27.  14.
#   97.  75.  33.  42.  54.  25.  10.   2.  58.   4.  50.  47.  35.  62.
#   63.  44.  53.  34.  76.   8.  72.  66.  45.  65.  77.  68.  80.  61.
#   92.   5.  96.  86.  85.  82.  88.  98.  94.  56.  95.  91.  99.  81.
#   84.  87.]
# 1.0
# 100.0

# %%
df['Speed Level'] = df['Speed Level'] / df['Speed Level'].max()
df
# Out:
#       importtIndex_Monster   Monster Criminal record     Age Gender  \
# 0                     2101     witch              no   526.0      f
# 1                     9299    zombie             yes    46.0      m
# 2                     6824   vampire              no   442.0      m
# 3                     6773   vampire              no   551.0      f
# 4                     9624    zombie             yes   150.0      f
# ...                    ...       ...             ...     ...    ...
# 9995                  4633  skeleton             yes  1836.0      f
# 9996                  6713  werewolf              no    77.0      f
# 9997                  5535     witch              no   484.0      m
# 9998                  8635   vampire              no   824.0      f
# 9999                  6340     witch              no   442.0      m
#
#       Height in cm  Speed Level  Strength Level   Allergy Favorite Food  \
# 0            197.0         0.16             1.0  hazelnut         brain
# 1            184.0         0.20             7.0  cat hair        humans
# 2            192.0         0.21             7.0  sunlight   pesto pasta
# 3            167.0         0.43             6.0    garlic        humans
# 4            176.0         0.17             1.0   pumpkin         brain
# ...            ...          ...             ...       ...           ...
# 9995         152.0         0.01             2.0    silver          rats
# 9996         192.0         0.74             4.0    silver          rats
# 9997         175.0         0.18             2.0    garlic   pesto pasta
# 9998         152.0         0.31             5.0    silver       lasagna
# 9999         189.0         0.21             9.0   pumpkin       lasagna
#
#           Age Bin
# 0           adult
# 1            baby
# 2           adult
# 3           adult
# 4     young adult
# ...           ...
# 9995          old
# 9996         baby
# 9997        adult
# 9998   middle age
# 9999        adult
#
# [10000 rows x 11 columns]

# %%
print(df['Strength Level'].min())
print(df['Strength Level'].max())
# Out:
# 1.0
# 10.0

# %%
df['Strength Level'] = df['Strength Level'] / df['Strength Level'].max()
df
# Out:
#       importtIndex_Monster   Monster Criminal record     Age Gender  \
# 0                     2101     witch              no   526.0      f
# 1                     9299    zombie             yes    46.0      m
# 2                     6824   vampire              no   442.0      m
# 3                     6773   vampire              no   551.0      f
# 4                     9624    zombie             yes   150.0      f
# ...                    ...       ...             ...     ...    ...
# 9995                  4633  skeleton             yes  1836.0      f
# 9996                  6713  werewolf              no    77.0      f
# 9997                  5535     witch              no   484.0      m
# 9998                  8635   vampire              no   824.0      f
# 9999                  6340     witch              no   442.0      m
#
#       Height in cm  Speed Level  Strength Level   Allergy Favorite Food  \
# 0            197.0         0.16             0.1  hazelnut         brain
# 1            184.0         0.20             0.7  cat hair        humans
# 2            192.0         0.21             0.7  sunlight   pesto pasta
# 3            167.0         0.43             0.6    garlic        humans
# 4            176.0         0.17             0.1   pumpkin         brain
# ...            ...          ...             ...       ...           ...
# 9995         152.0         0.01             0.2    silver          rats
# 9996         192.0         0.74             0.4    silver          rats
# 9997         175.0         0.18             0.2    garlic   pesto pasta
# 9998         152.0         0.31             0.5    silver       lasagna
# 9999         189.0         0.21             0.9   pumpkin       lasagna
#
#           Age Bin
# 0           adult
# 1            baby
# 2           adult
# 3           adult
# 4     young adult
# ...           ...
# 9995          old
# 9996         baby
# 9997        adult
# 9998   middle age
# 9999        adult
#
# [10000 rows x 11 columns]

# %%
df.to_csv('cleanup_suspects.csv',index = False)
