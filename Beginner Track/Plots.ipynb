# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


df_crimes = pd.read_csv("cleanup_Crime_Dataset.csv")
df_suspects = pd.read_csv("cleanup_suspects.csv")

# %% [markdown]
# Wie sind die Monster Typen verteilt?

# %%
# monster distribution
df_grouped = df_crimes.groupby("Monster involved")["Index_Crimes"].count()

# formatting
bars = plt.barh(df_grouped.index, df_grouped.values, color="#fbff02")
plt.xlabel("Count", color="white")
plt.ylabel("Monster Type", color="white")
plt.xticks(rotation=0, color="white")
plt.title("Distribution of Monster Types", color="white")
plt.show()

# Region Info
max_region= df_crimes.groupby('Region')['Index_Crimes'].count().sort_values(ascending=False).head(1)
print("max:",max_region.index[0], int(max_region.values[0]),"- of 10,000")
related_region = df_crimes[df_crimes['Region'] == 'village'].groupby('Region')['Index_Crimes'].count()
print("mayor:",related_region.index[0], int(related_region.values[0]),"- of 10,000")
print()

#Crime Type Info
max_crime_type= df_crimes.groupby('Crime Type')['Index_Crimes'].count().sort_values(ascending=False).head(1)
print("max:",max_crime_type.index[0], int(max_crime_type.values[0]),"- of 10,000")
related_crime_type = df_crimes[df_crimes['Crime Type'] == 'kidnapping'].groupby('Crime Type')['Index_Crimes'].count()
print("mayor:",related_crime_type.index[0], int(related_crime_type.values[0]),"- of 10,000")
print()

#Crime Weapon Info
max_crime_weapon= df_crimes.groupby('Crime Weapon')['Index_Crimes'].count().sort_values(ascending=False).head(1)
print("max:",max_crime_weapon.index[0], int(max_crime_weapon.values[0]),"- of 10,000")
related_crime_weapon = df_crimes[df_crimes['Crime Weapon'] == 'knife'].groupby('Crime Weapon')['Index_Crimes'].count()
print("mayor:",related_crime_weapon.index[0], int(related_crime_weapon.values[0]),"- of 10,000")
print()

#Time of Day Info
max_time_of_day= df_crimes.groupby('Time of Day')['Index_Crimes'].count().sort_values(ascending=False).head(1)
print("max:",max_time_of_day.index[0], int(max_time_of_day.values[0]),"- of 10,000")
related_time_of_day = df_crimes[df_crimes['Time of Day'] == 'day'].groupby('Time of Day')['Index_Crimes'].count()
print("mayor:",related_time_of_day.index[0], int(related_time_of_day.values[0]),"- of 10,000")
print()

#Time of Day Info
max_evidence_found= df_crimes.groupby('Evidence Found')['Index_Crimes'].count().sort_values(ascending=False).head(1)
print("max:",max_evidence_found.index[0], int(max_evidence_found.values[0]),"- of 10,000")
related_evidence_found = df_crimes[df_crimes['Evidence Found'] == 'bones'].groupby('Evidence Found')['Index_Crimes'].count()
print("mayor:",related_evidence_found.index[0], int(related_evidence_found.values[0]),"- of 10,000")
print()
# Out:
# max: castle 2476 - of 10,000
# mayor: village 2301 - of 10,000
#
# max: assault 2656 - of 10,000
# mayor: kidnapping 1490 - of 10,000
#
# max: knife 2717 - of 10,000
# mayor: knife 2717 - of 10,000
#
# max: night 5240 - of 10,000
# mayor: day 1493 - of 10,000
#
# max: cloak 2309 - of 10,000
# mayor: bones 2049 - of 10,000

# %% [markdown]
# Boxplott zu Alter unter Verbrechern

# %%
df_criminals = df_suspects.copy() 
df_criminals = df_criminals[df_criminals['Criminal record'] == 'yes']
age_plot = plt.boxplot(df_criminals["Age"])

df_criminals = df_suspects[df_suspects["Criminal record"] == 'yes']

q1 = df_criminals["Age"].quantile(0.25)
median = df_criminals["Age"].median()
q3 = df_criminals["Age"].quantile(0.75)
low = df_criminals["Age"].min()
high = df_criminals["Age"].max()

labels = [
    f"Low: {low:.1f}",
    f"Q1: {q1:.1f}",
    f"Median: {median:.1f}",
    f"Q3: {q3:.1f}",
    f"High: {high:.1f}",
]
handles = [mpatches.Patch(color="none", label=lbl) for lbl in labels]
plt.legend(handles=handles, facecolor="#37373b", edgecolor="white", labelcolor="white", loc="upper right")
plt.title('Boxplot of age for suspects with criminal record')
plt.ylabel("Age", color="white")
plt.xticks([1], ["Criminals"], color="white")
plt.ylim(-100, 2000)
plt.tight_layout()
plt.show()

# %% [markdown]
# Welche Monster begingen in der Vergangenheit ähnliche Verbrechen?
#
# (Kidnapping, am Tag, mit Messer, im Dorf, Knochen zurückgelassen) mind 4/5 erfüllt

# %%
criteria = [
    df_crimes["Crime Weapon"] == "knife",
    df_crimes["Time of Day"] == "day",
    df_crimes["Region"] == "village",
    df_crimes["Crime Type"] == "kidnapping",
    df_crimes["Evidence Found"] == "bones"
]

df_very_similar_crime = df_crimes[sum(criteria) >= 4]

df_very_similar_crime = (
    df_very_similar_crime.groupby("Monster involved")["Index_Crimes"].count()
)
df_very_similar_crime.plot(kind="bar")

# Formatting
plt.style.use("dark_background")
bars = plt.bar(df_very_similar_crime.index, df_very_similar_crime.values, color="#fbff02")
plt.xlabel("Monster Type", color="white")
plt.ylabel("Count", color="white")
plt.xticks(rotation=0, color="white")
plt.title("Which monsters committed similar crimes in the past? min(4/5)", color="white")
plt.show()

# %% [markdown]
# Welche Monster begingen in der Vergangenheit sehr ähnliche Verbrechen?
#
# (Kidnapping, am Tag, mit Messer, im Dorf, Knochen zurückgelassen) 5/5 erfüllt

# %%
df_very_similar_crime = df_crimes.copy()
df_very_similar_crime = df_very_similar_crime[df_crimes['Crime Weapon'] == 'knife']
df_very_similar_crime = df_very_similar_crime[df_very_similar_crime['Time of Day'] == 'day']
df_very_similar_crime = df_very_similar_crime[df_very_similar_crime['Region'] == 'village']
df_very_similar_crime = df_very_similar_crime[df_very_similar_crime['Crime Type'] == 'kidnapping']
df_very_similar_crime = df_very_similar_crime[df_very_similar_crime['Evidence Found'] == 'bones']
df_very_similar_crime = df_very_similar_crime.groupby("Monster involved")["Index_Crimes"].count()
df_very_similar_crime.plot(kind='bar')

# Formatting:
plt.style.use("dark_background")
bars = plt.bar(df_very_similar_crime.index, df_very_similar_crime.values, color="#fbff02")
plt.xlabel("Monster Type", color="white")
plt.ylabel("Count", color="white")
plt.xticks(rotation=0, color="white")
plt.title("Which monsters committed very similar crimes in the past? (5/5)", color="white")
plt.show()

# %% [markdown]
# Welche Monster begehen die meisten Straftaten ?

# %%
df_crime_rates = df_suspects.copy()
df_crime_rates = (
    df_crime_rates.groupby("Monster")["Criminal record"]
    .apply(lambda x: (x == 'yes').sum() / len(x) * 10)
    .sort_values(ascending=True)
)
df_crime_rates.plot(kind='barh')

# Formatting:
bars = plt.barh(df_crime_rates.index, df_crime_rates.values, color="#fbff02")
plt.xlabel("Criminals per 10", color="white")
plt.ylabel("Monster Type", color="white")
plt.xticks(rotation=0, color="white")
plt.title("Crime rate of each Monster Type (/10)", color="white")
plt.show()

# %% [markdown]
# Welche Monster Typen sind am fähigsten Verbrechen zu begehen?
#
# (Speed : Strength = 50 : 50)

# %%
df_avg_ability = df_suspects.copy()

df_avg_ability["Ability Score"] = ((df_avg_ability["Strength Level"] + df_avg_ability["Speed Level"]) / 2) * 99 + 1

df_avg_ability = df_avg_ability.groupby('Monster')['Ability Score'].mean().sort_values(ascending=False)
df_avg_ability.plot(kind='barh')

# Formatting:
bars = plt.barh(df_avg_ability.index, df_avg_ability.values, color="#fbff02")
plt.xlabel("Ability Level (1-100)", color="white")
plt.ylabel("Monster Type", color="white")
plt.xticks(rotation=0, color="white")
plt.title("Which Monster Types are most capable of committing a crime? (Speed 50 : 50 Strength)", color="white")
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# Fähigkeit in Relation zu Häufigkeit pro Monster Typ
#
# (Fähigkeit 50 : 50 Häufigkeit)

# %%
df_avg_ability_copy = df_avg_ability.copy()
df_avg_ability_copy = df_avg_ability_copy.reset_index()
df_avg_ability_copy.columns = ['Monster', 'Ability Score']

# %%
df_crime_rates_copy = df_crime_rates.copy()
df_crime_rates_copy = df_crime_rates_copy.reset_index()
df_crime_rates_copy.columns = ['Monster',"Crime Rate" ]

# %%
df_caution_level = df_suspects.merge(df_avg_ability, on="Monster", how="left")
df_caution_level = df_caution_level.merge(df_crime_rates, on="Monster", how="left")

df_caution_level["Crime_Level_norm"] = (
    df_caution_level["Criminal record_y"] - df_caution_level["Criminal record_y"].min()
) / (df_caution_level["Criminal record_y"].max() - df_caution_level["Criminal record_y"].min())

df_caution_level['ability_norm'] = df_caution_level['Ability Score'] / 100
 
df_caution_level["Caution_Level"] = ((df_caution_level["ability_norm"] + df_caution_level["Crime_Level_norm"]) / 2) * 99 + 1

df_caution_level = df_caution_level.groupby('Monster')[['Caution_Level']].mean().sort_values(by='Caution_Level', ascending=False)
df_caution_level.plot(kind='bar', color="#fbff02")

# Formatting:
plt.style.use("dark_background")
plt.xlabel("Monster Type", color="white")
plt.ylabel("Caution Level (1-100)", color="white")
plt.xticks(rotation=45, color="white", ha='right')
plt.title("Caution Level by Monster Type (Probability 50 : 50 Capability)", color="white")
plt.legend().remove()
plt.ylim(0,100)
plt.show()

# %% [markdown]
# Ausschlusskriterien der Suspects (Allergien)

# %%
df_possible_criminals = df_suspects.copy()
df_possible_criminals = df_possible_criminals[df_possible_criminals['Allergy'] != 'sunlight']
df_possible_criminals = df_possible_criminals[df_possible_criminals['Age'] > 12]
df_possible_criminals
# Out:
#       importtIndex_Monster   Monster Criminal record     Age Gender  \
# 0                     2101     witch              no   526.0      f
# 1                     9299    zombie             yes    46.0      m
# 3                     6773   vampire              no   551.0      f
# 4                     9624    zombie             yes   150.0      f
# 5                     7494    zombie             yes   100.0      m
# ...                    ...       ...             ...     ...    ...
# 9995                  4633  skeleton             yes  1836.0      f
# 9996                  6713  werewolf              no    77.0      f
# 9997                  5535     witch              no   484.0      m
# 9998                  8635   vampire              no   824.0      f
# 9999                  6340     witch              no   442.0      m
#
#       Height in cm  Speed Level  Strength Level   Allergy Favorite Food  \
# 0            197.0         0.16             0.1  hazelnut         brain
# 1            184.0         0.20             0.7  cat hair        humans
# 3            167.0         0.43             0.6    garlic        humans
# 4            176.0         0.17             0.1   pumpkin         brain
# 5            180.0         0.20             0.1    garlic   pesto pasta
# ...            ...          ...             ...       ...           ...
# 9995         152.0         0.01             0.2    silver          rats
# 9996         192.0         0.74             0.4    silver          rats
# 9997         175.0         0.18             0.2    garlic   pesto pasta
# 9998         152.0         0.31             0.5    silver       lasagna
# 9999         189.0         0.21             0.9   pumpkin       lasagna
#
#           Age Bin
# 0           adult
# 1            baby
# 3           adult
# 4     young adult
# 5            teen
# ...           ...
# 9995          old
# 9996         baby
# 9997        adult
# 9998   middle age
# 9999        adult
#
# [7801 rows x 11 columns]

# %% [markdown]
# Motivationen der Suspects (favorite food)

# %%
df_suspects_with_motivation = df_suspects.copy()
df_suspects_with_motivation = df_suspects_with_motivation[df_suspects_with_motivation["Favorite Food"].isin(["brain", "humans"])]
df_suspects_with_motivation
# Out:
#       importtIndex_Monster   Monster Criminal record    Age Gender  \
# 0                     2101     witch              no  526.0      f
# 1                     9299    zombie             yes   46.0      m
# 3                     6773   vampire              no  551.0      f
# 4                     9624    zombie             yes  150.0      f
# 7                     9574  skeleton              no  999.0      f
# ...                    ...       ...             ...    ...    ...
# 9959                  3447     witch              no  573.0      m
# 9968                  3166     witch              no  431.0      f
# 9971                  9955    zombie             yes   86.0      f
# 9978                   659   vampire             yes  521.0      m
# 9979                  8558   vampire              no    1.0      m
#
#       Height in cm  Speed Level  Strength Level   Allergy Favorite Food  \
# 0            197.0         0.16             0.1  hazelnut         brain
# 1            184.0         0.20             0.7  cat hair        humans
# 3            167.0         0.43             0.6    garlic        humans
# 4            176.0         0.17             0.1   pumpkin         brain
# 7            184.0         0.38             0.3    silver         brain
# ...            ...          ...             ...       ...           ...
# 9959         153.0         0.26             0.5  hazelnut        humans
# 9968         193.0         0.16             0.6  hazelnut         brain
# 9971         158.0         0.21             0.3  sunlight        humans
# 9978         165.0         0.54             0.1    garlic        humans
# 9979         191.0         0.47             0.5    silver        humans
#
#           Age Bin
# 0           adult
# 1            baby
# 3           adult
# 4     young adult
# 7      middle age
# ...           ...
# 9959        adult
# 9968        adult
# 9971         teen
# 9978        adult
# 9979         baby
#
# [3928 rows x 11 columns]
