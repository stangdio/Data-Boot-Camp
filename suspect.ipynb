# %%
import pandas as pd

df = pd.read_csv('Suspects_Dataset.csv')
df
# Out:
#       Index_Monster   Monster Criminal record     Age Gender  Height in cm  \
# 0              2101     Witch              No   526.0      F         197.0
# 1              9299    Zombie             Yes    46.0      M         184.0
# 2              6824   Vampire              No   442.0      M         192.0
# 3              6773   Vampire              No   551.0      F         167.0
# 4              9624    Zombie             Yes   150.0      F         176.0
# ...             ...       ...             ...     ...    ...           ...
# 9995           4633  Skeleton             Yes  1836.0      F         152.0
# 9996           6713  Werewolf              No    77.0      F         192.0
# 9997           5535     Witch              No   484.0      M         175.0
# 9998           8635   Vampire              No   824.0      F         152.0
# 9999           6340     Witch              No   442.0      M         189.0
#
#       Speed Level  Strength Level   Allergy Favorite Food
# ...
